# %% [markdown]
# # Life Expectancy vs. GDP Data Analysis and Visualization

# %% [markdown]
# ## Loading the necessary libraries
# Load the necessary libraries to analyse and visualize the dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset
# Load the dataset into pandas DataFrame and print top 5 rows

# %%
df = pd.read_csv('./all_data.csv')
df.head()
# Out:
#   Country  Year  Life expectancy at birth (years)           GDP
# 0   Chile  2000                              77.3  7.786093e+10
# 1   Chile  2001                              77.3  7.097992e+10
# 2   Chile  2002                              77.8  6.973681e+10
# 3   Chile  2003                              77.9  7.564346e+10
# 4   Chile  2004                              78.0  9.921039e+10

# %% [markdown]
# The Dataframe has **5** columns:
#  - **Country:** Categorical variable (nominal)
#  - **Year:** Quantitative variable (integer)
#  - **Life expectancy at birth (years):** Quantitative variable (float)
#  - **GDP:** Quantitative variable

# %% [markdown]
# ## Get the concise summary of the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Country                           96 non-null     object
#  1   Year                              96 non-null     int64
#  2   Life expectancy at birth (years)  96 non-null     float64
#  3   GDP                               96 non-null     float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 3.1+ KB

# %% [markdown]
# ## Get the Statistical Summary of the dataset
# The pandas.describe() method provides a summary of the central tendency, dispersion, and shape of a dataset’s distribution, excluding NaN values. It is particularly useful for getting a quick statistical overview of the numerical columns in a DataFrame.

# %%
df.describe(include='all')
# Out:
#        Country         Year  Life expectancy at birth (years)           GDP
# count       96    96.000000                         96.000000  9.600000e+01
# unique       6          NaN                               NaN           NaN
# top      Chile          NaN                               NaN           NaN
# freq        16          NaN                               NaN           NaN
# mean       NaN  2007.500000                         72.789583  3.880499e+12
# std        NaN     4.633971                         10.672882  5.197561e+12
# min        NaN  2000.000000                         44.300000  4.415703e+09
# 25%        NaN  2003.750000                         74.475000  1.733018e+11
# 50%        NaN  2007.500000                         76.750000  1.280220e+12
# 75%        NaN  2011.250000                         78.900000  4.067510e+12
# max        NaN  2015.000000                         81.000000  1.810000e+13

# %% [markdown]
# ## Exploratory Data Analysis

# %%
df['Country'].nunique()
# Out:
# 6

# %% [markdown]
# There are 6 unique countries in our dataset

# %%
df['Country'].unique()
# Out:
# array(['Chile', 'China', 'Germany', 'Mexico', 'United States of America',
#        'Zimbabwe'], dtype=object)

# %%
df['Country'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# By visualizing the Country variable we can see that the destribution follows the complete **Uniform Distribution**

# %%
df['Year'].nunique()
# Out:
# 16

# %%
df['Year'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015], dtype=int64)

# %%
df['Life expectancy at birth (years)'].nunique()
# Out:
# 69

# %% [markdown]
# ### Distribution of Life Expectancy

# %%
# Plot the distribution of life expectancy
plt.figure(figsize=(10, 6))
sns.histplot(df['Life expectancy at birth (years)'])
plt.title('Distribution of Life Expectancy at Birth')
plt.xlabel('Life Expectancy at Birth (years)')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# The histogram shows that the life expectancy variable's distribution is skewed towards the left

# %%
sns.boxplot(df['Life expectancy at birth (years)'])
plt.title('Life expectancy at birth in years distribution')
plt.xlabel('Life expectancy at birth in years')
plt.show()

# %% [markdown]
# By visualizing the boxplot we can notice that are many outliers in our variable

# %% [markdown]
# ### Distribution of GDP

# %%
# Plot the distribution of GDP
plt.figure(figsize=(10, 6))
sns.histplot(df['GDP'], kde=True)
plt.title('Distribution of GDP')
plt.xlabel('GDP')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Life Expectancy Over Time
# We'll plot life expectancy over time for each country to see trends.

# %%
# Plot life expectancy over time for each country
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='Year', y='Life expectancy at birth (years)', hue='Country')
plt.title('Life Expectancy at Birth Over Time')
plt.xlabel('Year')
plt.ylabel('Life Expectancy at Birth (years)')
plt.legend(title='Country')
plt.show()
# Out:
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### GDP Over Time
# We'll plot GDP over time for each country to see economic trends.

# %%
# Plot GDP over time for each country
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='Year', y='GDP', hue='Country')
plt.title('GDP Over Time')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.legend(title='Country')
plt.show()
# Out:
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Relationship Between Life Expectancy and GDP
# We'll explore the relationship between life expectancy and GDP.

# %%
# Plot the relationship between life expectancy and GDP
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='GDP', y='Life expectancy at birth (years)', hue='Country')
plt.title('Relationship Between Life Expectancy and GDP')
plt.xlabel('GDP')
plt.ylabel('Life Expectancy at Birth (years)')
plt.legend(title='Country')
plt.show()

# %% [markdown]
# ### Logarithmic Transformation
# Because the values for the GDP are so high we are not able to visualize the relationship. Let's address this by transforming the GDP to more manageable scale. We'll use a logarithmic transformation, which is a common technique to handle large ranges of values and make trends more visible.

# %%
# Apply logarithmic transformation to GDP 
df['Log GDP'] = np.log(df['GDP'])

# %%
# Plot log GDP over time for each country
plt.figure(figsize=(14, 8))
sns.lineplot(data=df, x='Year', y='Log GDP', hue='Country')
plt.title('Log GDP Over Time')
plt.xlabel('Year')
plt.ylabel('Log GDP')
plt.legend(title='Country')
plt.show()
# Out:
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\atash\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Plot the relationship between life expectancy and log GDP
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Log GDP', y='Life expectancy at birth (years)', hue='Country')
plt.title('Relationship Between Life Expectancy and Log GDP')
plt.xlabel('Log GDP')
plt.ylabel('Life Expectancy at Birth (years)')
plt.legend(title='Country')
plt.show()

# %% [markdown]
# ### Conclusion:
# 1. **What did you learn throughout the process?**
#
#     - **Loading Libraries and Dataset:** We start by loading the necessary libraries and the dataset.
#
#     - **Summary and Statistical Overview:** We use info() and describe() to get a concise and statistical summary of the dataset.
#
#     - **Exploratory Data Analysis (EDA):** We check unique values in categorical columns and visualize the distribution of life expectancy and GDP.
#
#     - **Logarithmic Transformation:** We apply a logarithmic transformation to the GDP values to make the trends more visible.
#
#     - **Trends Over Time:** We plot life expectancy and log GDP over time for each country.
#
#     - **Relationship Between Life Expectancy and Log GDP:** We explore the relationship between life expectancy and log GDP using a scatter plot.
# 2. **What are the key findings and takeaways?**
#     - Transform your column to more manageable scale to properly visualize the relationships.
